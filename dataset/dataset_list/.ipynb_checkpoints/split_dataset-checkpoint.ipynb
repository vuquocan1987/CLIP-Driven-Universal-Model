# %%
from random import sample
import os
os.chdir('..')

def split_files(file_name):
    with open(file_name + '.txt', 'r') as f:
        line_set=[]
        lines = f.readlines()
        for line in lines:
            line_set.append(line)
    line_set = sorted(line_set)

    train_set = sample(line_set, int(len(line_set)*0.8))
    train_set = sorted(train_set)
    with open(file_name + '_train.txt', 'w') as f:
        for line in train_set:
            f.write(line)

    rest_set = []
    for line in line_set:
        if line in train_set:
            pass
        else:
            rest_set.append(line)

    val_set = sample(rest_set, int(len(rest_set)*0.25))
    val_set = sorted(val_set)

    with open(file_name + '_val.txt', 'w') as f:
        for line in val_set:
            f.write(line)

    with open(file_name + '_test.txt', 'w') as f:
        for line in rest_set:
            if line in val_set:
                pass
            else:
                f.write(line)
split_files("MOTS")
split_files("MOTS_simple")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 39
#      37             else:
#      38                 f.write(line)
# ---> 39 split_files("MOTS")
#      40 split_files("MOTS_simple")
#
# Cell In[2], line 6, in split_files(file_name)
#       5 def split_files(file_name):
# ----> 6     with open(file_name + '.txt', 'r') as f:
#       7         line_set=[]
#       8         lines = f.readlines()
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'MOTS.txt'

# %%
pth_set = []
with open('PAOT_10_inner_train.txt') as f:
    lines = f.readlines()
    for line in lines:
        item = line.split()
        if item[0][-3:] == 'npy':
            pth_set.append([item[0][:-4], item[1][:-4]])
        else:
            pth_set.append([item[0], item[1]])

with open('PAOT_10_inner_train1.txt', 'w') as f:
    for pth in pth_set:
        f.write(pth[0])
        f.write('\t')
        f.write(pth[1])
        f.write('\n')
